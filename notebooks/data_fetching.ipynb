# %%
a="hello"
b="world"
print(a +" "+ b)
# Out:
# hello world

# %%
guvi = {
    "source": "Cricbuzz API via RapidAPI",
    "purpose": "Live cricket data ingestion",
    "frontend": "Streamlit dashboard",
    "features": [
        "Live score updates",
        "Match metadata display",
        "Player stats visualization",
        "Venue-based filtering"
    ]
}

# Print each key-value pair one by one
for key, value in guvi.items():
    print(f"{key}:")
    if isinstance(value, list):
        for item in value:
            print(f"  - {item}")
    else:
        print(f"  {value}")
    print()  # Add spacing between sections
# Out:
# source:
#   Cricbuzz API via RapidAPI
#
# purpose:
#   Live cricket data ingestion
#
# frontend:
#   Streamlit dashboard
#
# features:
#   - Live score updates
#   - Match metadata display
#   - Player stats visualization
#   - Venue-based filtering

# %% [markdown]
# 36954114camsh2b433ff821256e9p15a211jsn1128402c355f

# %%
import requests
import pandas as pd
from datetime import datetime

# Helper to convert epoch millis → YYYY-MM-DD HH:MM
def convert_ts(ts):
    return datetime.utcfromtimestamp(int(ts) / 1000).strftime("%Y-%m-%d %H:%M") if ts else None

# Fetch API data
def fetch_api(url, headers=None, params=None):
    if headers is None:
        headers = {
	        "x-rapidapi-key": "36954114camsh2b433ff821256e9p15a211jsn1128402c355f",
	        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
        }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# Helper: Format innings scores
def format_scores(team_score):
    if not team_score:
        return ""
    scores = []
    for key, innings in team_score.items():
        if innings:
            runs = innings.get("runs", 0)
            wickets = innings.get("wickets", 0)
            overs = innings.get("overs", 0)
            scores.append(f"{runs}/{wickets} ({overs} ov)")
    return " | ".join(scores)

# Extract recent matches
def extract_recent_matches(data):
    all_matches = []
    type_matches = data.get("typeMatches", [])

    for t in type_matches:
        series_matches = t.get("seriesMatches", [])
        for s in series_matches:
            series_ad_wrapper = s.get("seriesAdWrapper", {})
            matches = series_ad_wrapper.get("matches", [])
            for m in matches:
                info = m.get("matchInfo", {})
                score = m.get("matchScore", {})

                team1_score = format_scores(score.get("team1Score"))
                team2_score = format_scores(score.get("team2Score"))

                start_dt = datetime.fromtimestamp(int(info.get("startDate", 0))/1000)

                match_data = {
                    "match_id": info.get("matchId"),
                    "match_desc": info.get("matchDesc"),
                    "team1": info.get("team1", {}).get("teamName"),
                    "team2": info.get("team2", {}).get("teamName"),
                    "start_date": start_dt,
                    "status": info.get("status"),
                    "state": info.get("state"),
                    "venue": info.get("venueInfo", {}).get("ground"),
                    "venue_city": info.get("venueInfo", {}).get("city"),
                    "series_name": info.get("seriesName"),
                    "match_format": info.get("matchFormat"),
                    "team1_score": team1_score,
                    "team2_score": team2_score
                }
                all_matches.append(match_data)

    return pd.DataFrame(all_matches)

# Call for recent matches
url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"
data = fetch_api(url)
df_recent_matches = extract_recent_matches(data)

print("Recent Matches DataFrame:")
df_recent_matches
# Out:
# Recent Matches DataFrame:
#     match_id                         match_desc                       team1  \
# 0     130168  Super Fours, 18th Match (A1 v B1)                       India
# 1     130146  Super Fours, 16th Match (A1 v B2)                       India
# 2     130129  Super Fours, 14th Match (A1 v A2)                    Pakistan
# 3     130157  Super Fours, 17th Match (A2 v B2)                    Pakistan
# 4     130140  Super Fours, 15th Match (A2 v B1)                   Sri Lanka
# 5     121345                           1st T20I                       Nepal
# 6     134777                 3rd Match, Group B                      Uganda
# 7     134760                 1st Match, Group A                     Namibia
# 8     134771                 2nd Match, Group A                      Malawi
# 9     134782                 4th Match, Group B                    Botswana
# 10    105858                           3rd T20I                     Ireland
# 11    116828                              Final      Guyana Amazon Warriors
# 12    131009                      3rd Youth ODI                   India U19
# 13    130998                      2nd Youth ODI                   India U19
# 14    130993                      1st Youth ODI               Australia U19
# 15    133495                          6th Match           Western Australia
# 16    133484                          5th Match           Western Australia
# 17    119852                2nd Unofficial Test                 Australia A
# 18    113289                         70th Match                      Durham
# 19    113280                         69th Match              Worcestershire
# 20    113271                         67th Match                Warwickshire
# 21    113262                         66th Match                    Somerset
# 22    113274                         68th Match                      Surrey
# 23    113670                         55th Match                   Middlesex
# 24    113658                         53rd Match              Leicestershire
# 25    113661                         54th Match                  Derbyshire
# 26    113676                         56th Match                   Glamorgan
# 27    135151                            1st ODI  United Arab Emirates Women
# 28    134991                          3rd Match             Hong Kong Women
# 29    135035                              Final             Hong Kong Women
# 30    135002                          4th Match                 China Women
# 31    135024                 3rd place play-off              Mongolia Women
# 32    135008                          5th Match              Mongolia Women
# 33    135013                          6th Match             Hong Kong Women
# 34    135118                          6th Match           New Zealand Women
# 35    135079                          1st Match           New Zealand Women
# 36    135107                          5th Match            Bangladesh Women
# 37    135096                          3rd Match             Sri Lanka Women
# 38    135090                          2nd Match          South Africa Women
# 39    135101                          4th Match               England Women
# 40    133699                            3rd ODI          South Africa Women
#
#                      team2          start_date  \
# 0                Sri Lanka 2025-09-26 20:00:00
# 1               Bangladesh 2025-09-24 20:00:00
# 2                    India 2025-09-21 20:00:00
# 3               Bangladesh 2025-09-25 20:00:00
# 4                 Pakistan 2025-09-23 20:00:00
# 5              West Indies 2025-09-27 20:00:00
# 6                 Zimbabwe 2025-09-26 17:20:00
# 7                    Kenya 2025-09-26 13:00:00
# 8                  Nigeria 2025-09-26 13:00:00
# 9                 Tanzania 2025-09-26 17:20:00
# 10                 England 2025-09-21 18:00:00
# 11  Trinbago Knight Riders 2025-09-22 05:30:00
# 12           Australia U19 2025-09-26 09:30:00
# 13           Australia U19 2025-09-24 09:30:00
# 14               India U19 2025-09-21 09:30:00
# 15         South Australia 2025-09-24 06:00:00
# 16              Queensland 2025-09-21 09:30:00
# 17                 India A 2025-09-23 09:30:00
# 18               Yorkshire 2025-09-24 15:00:00
# 19                  Sussex 2025-09-24 15:00:00
# 20         Nottinghamshire 2025-09-24 15:00:00
# 21                   Essex 2025-09-24 15:00:00
# 22               Hampshire 2025-09-24 15:00:00
# 23         Gloucestershire 2025-09-24 15:00:00
# 24        Northamptonshire 2025-09-24 15:00:00
# 25                    Kent 2025-09-24 15:00:00
# 26              Lancashire 2025-09-24 15:00:00
# 27          Zimbabwe Women 2025-09-26 12:45:00
# 28          Mongolia Women 2025-09-22 06:30:00
# 29           Myanmar Women 2025-09-25 11:30:00
# 30           Myanmar Women 2025-09-22 11:30:00
# 31             China Women 2025-09-25 06:30:00
# 32           Myanmar Women 2025-09-23 06:30:00
# 33             China Women 2025-09-23 11:30:00
# 34             India Women 2025-09-27 15:00:00
# 35           India A Women 2025-09-25 09:30:00
# 36         Sri Lanka Women 2025-09-27 15:00:00
# 37          Pakistan Women 2025-09-25 15:00:00
# 38        Bangladesh Women 2025-09-25 15:00:00
# 39             India Women 2025-09-25 15:00:00
# 40          Pakistan Women 2025-09-22 16:00:00
#
#                                                status     state  \
# 0               Match tied (India Won the Super Over)  Complete
# 1                                India won by 41 runs  Complete
# 2                                 India won by 6 wkts  Complete
# 3                             Pakistan won by 11 runs  Complete
# 4                              Pakistan won by 5 wkts  Complete
# 5                                Nepal won by 19 runs  Complete
# 6                              Zimbabwe won by 5 wkts  Complete
# 7                             Namibia won by 136 runs  Complete
# 8                               Nigeria won by 9 wkts  Complete
# 9                              Tanzania won by 7 wkts  Complete
# 10                              England won by 6 wkts  Complete
# 11               Trinbago Knight Riders won by 3 wkts  Complete
# 12                          India U19 won by 167 runs  Complete
# 13                           India U19 won by 51 runs  Complete
# 14                            India U19 won by 7 wkts  Complete
# 15                   Western Australia won by 66 runs  Complete
# 16                           Queensland won by 2 wkts  Complete
# 17                              India A won by 5 wkts  Complete
# 18            Yorkshire won by an innings and 44 runs  Complete
# 19                               Sussex won by 3 wkts  Complete
# 20                     Nottinghamshire won by 10 wkts  Complete
# 21                                Essex won by 7 wkts  Complete
# 22                              Surrey won by 20 runs  Complete
# 23            Middlesex won by an innings and 67 runs  Complete
# 24                     Leicestershire won by 167 runs  Complete
# 25          Derbyshire won by an innings and 229 runs  Complete
# 26                           Lancashire won by 7 wkts  Complete
# 27          United Arab Emirates Women won by 36 runs  Complete
# 28                     Hong Kong Women won by 59 runs  Complete
# 29                     Hong Kong Women won by 26 runs  Complete
# 30                         Myanmar Women won by 1 wkt  Complete
# 31                          China Women won by 8 wkts  Complete
# 32                        Myanmar Women won by 7 wkts  Complete
# 33                          China Women won by 5 wkts  Complete
# 34            India Women won by 4 wkts  (DLS method)  Complete
# 35  India A Women won by 4 wkts  -  2nd inns reduc...  Complete
# 36                      Bangladesh Women won by 1 run  Complete
# 37                              No result due to rain  Complete
# 38                              No result due to rain  Complete
# 39                      England Women won by 153 runs  Complete
# 40                       Pakistan Women won by 6 wkts  Complete
#
#                                                 venue  \
# 0                 Dubai International Cricket Stadium
# 1                 Dubai International Cricket Stadium
# 2                 Dubai International Cricket Stadium
# 3                 Dubai International Cricket Stadium
# 4                                Sheikh Zayed Stadium
# 5                             Sharjah Cricket Stadium
# 6                                  Harare Sports Club
# 7                                  Harare Sports Club
# 8                              Takashinga Sports Club
# 9                              Takashinga Sports Club
# 10                                        The Village
# 11                                 Providence Stadium
# 12                                     Ian Healy Oval
# 13                                     Ian Healy Oval
# 14                                     Ian Healy Oval
# 15                                  Karen Rolton Oval
# 16                                 Allan Border Field
# 17  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 18                                         Headingley
# 19                                           New Road
# 20                                       Trent Bridge
# 21                                      County Ground
# 22                                      The Rose Bowl
# 23                                             Lord's
# 24                                      County Ground
# 25                                 St Lawrence Ground
# 26                                     Sophia Gardens
# 27                                 Queens Sports Club
# 28    Zhejiang University of Technology Cricket Field
# 29    Zhejiang University of Technology Cricket Field
# 30    Zhejiang University of Technology Cricket Field
# 31    Zhejiang University of Technology Cricket Field
# 32    Zhejiang University of Technology Cricket Field
# 33    Zhejiang University of Technology Cricket Field
# 34                   BCCI Centre of Excellence Ground
# 35                 BCCI Centre of Excellence Ground B
# 36                        Colombo Cricket Club Ground
# 37                        Colombo Cricket Club Ground
# 38                                R.Premadasa Stadium
# 39                   BCCI Centre of Excellence Ground
# 40                                    Gaddafi Stadium
#
#                    venue_city  \
# 0                       Dubai
# 1                       Dubai
# 2                       Dubai
# 3                       Dubai
# 4                   Abu Dhabi
# 5                     Sharjah
# 6                      Harare
# 7                      Harare
# 8                      Harare
# 9                      Harare
# 10                     Dublin
# 11                     Guyana
# 12                   Brisbane
# 13                   Brisbane
# 14                   Brisbane
# 15  Adelaide, South Australia
# 16                   Brisbane
# 17                    Lucknow
# 18                      Leeds
# 19                  Worcester
# 20                 Nottingham
# 21                 Chelmsford
# 22                Southampton
# 23                     London
# 24                Northampton
# 25                 Canterbury
# 26                    Cardiff
# 27                   Bulawayo
# 28                   Hangzhou
# 29                   Hangzhou
# 30                   Hangzhou
# 31                   Hangzhou
# 32                   Hangzhou
# 33                   Hangzhou
# 34                  Bengaluru
# 35                  Bengaluru
# 36                    Colombo
# 37                    Colombo
# 38                    Colombo
# 39                  Bengaluru
# 40                     Lahore
#
#                                           series_name match_format  \
# 0                                       Asia Cup 2025          T20
# 1                                       Asia Cup 2025          T20
# 2                                       Asia Cup 2025          T20
# 3                                       Asia Cup 2025          T20
# 4                                       Asia Cup 2025          T20
# 5                   West Indies vs Nepal in UAE, 2025          T20
# 6   ICC Mens T20 World Cup Africa Regional Final 2025          T20
# 7   ICC Mens T20 World Cup Africa Regional Final 2025          T20
# 8   ICC Mens T20 World Cup Africa Regional Final 2025          T20
# 9   ICC Mens T20 World Cup Africa Regional Final 2025          T20
# 10                      England tour of Ireland, 2025          T20
# 11                      Caribbean Premier League 2025          T20
# 12             India Under 19 tour of Australia, 2025          ODI
# 13             India Under 19 tour of Australia, 2025          ODI
# 14             India Under 19 tour of Australia, 2025          ODI
# 15             Australia Domestic One-Day Cup 2025-26          ODI
# 16             Australia Domestic One-Day Cup 2025-26          ODI
# 17                    Australia A tour of India, 2025         TEST
# 18              County Championship Division One 2025         TEST
# 19              County Championship Division One 2025         TEST
# 20              County Championship Division One 2025         TEST
# 21              County Championship Division One 2025         TEST
# 22              County Championship Division One 2025         TEST
# 23              County Championship Division Two 2025         TEST
# 24              County Championship Division Two 2025         TEST
# 25              County Championship Division Two 2025         TEST
# 26              County Championship Division Two 2025         TEST
# 27   United Arab Emirates Women tour of Zimbabwe 2025          ODI
# 28      Womens T20I Quadrangular Series in China 2025          T20
# 29      Womens T20I Quadrangular Series in China 2025          T20
# 30      Womens T20I Quadrangular Series in China 2025          T20
# 31      Womens T20I Quadrangular Series in China 2025          T20
# 32      Womens T20I Quadrangular Series in China 2025          T20
# 33      Womens T20I Quadrangular Series in China 2025          T20
# 34          ICC Womens World Cup Warm-up Matches 2025          ODI
# 35          ICC Womens World Cup Warm-up Matches 2025          ODI
# 36          ICC Womens World Cup Warm-up Matches 2025          ODI
# 37          ICC Womens World Cup Warm-up Matches 2025          ODI
# 38          ICC Womens World Cup Warm-up Matches 2025          ODI
# 39          ICC Womens World Cup Warm-up Matches 2025          ODI
# 40          South Africa Women tour of Pakistan, 2025          ODI
#
#                             team1_score                           team2_score
# 0                       202/5 (19.6 ov)                       202/5 (19.6 ov)
# 1                       168/6 (19.6 ov)                      127/10 (19.3 ov)
# 2                       171/5 (19.6 ov)                       174/4 (18.5 ov)
# 3                       135/8 (19.6 ov)                       124/9 (19.6 ov)
# 4                       133/8 (19.6 ov)                       138/5 (17.6 ov)
# 5                       148/8 (19.6 ov)                       129/9 (19.6 ov)
# 6                       152/9 (19.6 ov)                       157/5 (17.3 ov)
# 7                       241/5 (19.6 ov)                       105/7 (19.6 ov)
# 8                       88/10 (19.3 ov)                        92/1 (11.2 ov)
# 9                       122/6 (19.6 ov)                       124/3 (13.5 ov)
# 10                      154/8 (19.6 ov)                       155/4 (17.1 ov)
# 11                      130/8 (19.6 ov)                       133/7 (17.6 ov)
# 12                      280/9 (49.6 ov)                      113/10 (28.3 ov)
# 13                     300/10 (49.4 ov)                      249/10 (47.2 ov)
# 14                      225/9 (49.6 ov)                       227/3 (30.3 ov)
# 15                      298/9 (49.6 ov)                      232/10 (44.3 ov)
# 16                      321/9 (49.6 ov)                       323/8 (49.1 ov)
# 17  420/10 (97.2 ov) | 185/10 (46.5 ov)    194/10 (52.5 ov) | 413/5 (91.3 ov)
# 18  346/10 (103.2 ov) | 85/10 (44.5 ov)                     475/10 (141.4 ov)
# 19  123/10 (34.4 ov) | 287/10 (74.6 ov)     350/10 (65.4 ov) | 63/7 (15.2 ov)
# 20  258/10 (85.4 ov) | 133/10 (53.6 ov)      374/10 (97.3 ov) | 20/0 (3.4 ov)
# 21  433/10 (122.2 ov) | 99/10 (33.3 ov)    438/10 (105.6 ov) | 99/3 (18.1 ov)
# 22  147/10 (47.2 ov) | 281/10 (85.3 ov)   248/10 (79.4 ov) | 160/10 (58.6 ov)
# 23                     634/9 (147.4 ov)   286/10 (88.1 ov) | 281/10 (89.6 ov)
# 24  429/10 (107.5 ov) | 260/5 (62.6 ov)  189/10 (57.2 ov) | 333/10 (105.5 ov)
# 25                     698/6 (144.6 ov)   271/10 (85.4 ov) | 198/10 (61.5 ov)
# 26  265/10 (73.2 ov) | 241/10 (84.6 ov)    374/10 (96.4 ov) | 134/3 (19.6 ov)
# 27                      222/5 (49.6 ov)                      186/10 (46.3 ov)
# 28                      146/4 (19.6 ov)                        87/5 (19.6 ov)
# 29                       96/6 (19.6 ov)                        70/6 (19.6 ov)
# 30                      53/10 (19.6 ov)                        55/9 (12.5 ov)
# 31                       89/9 (19.6 ov)                        90/2 (14.4 ov)
# 32                       44/9 (20.0 ov)                         45/3 (7.0 ov)
# 33                     100/10 (19.4 ov)                       102/5 (19.5 ov)
# 34                      232/8 (41.6 ov)                       237/6 (40.2 ov)
# 35                      273/9 (49.6 ov)                       226/6 (39.3 ov)
# 36                      242/8 (49.6 ov)                      241/10 (49.5 ov)
# 37                        33/1 (7.3 ov)
# 38                        45/3 (8.6 ov)
# 39                      340/9 (49.6 ov)                      187/10 (33.6 ov)
# 40                     115/10 (25.5 ov)                       117/4 (30.6 ov)

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Step 1: Create MySQL engine with your credentials
def create_mysql_engine():
    """
    Creates and returns a SQLAlchemy MySQL engine using your credentials.
    """
    return create_engine("mysql+pymysql://root:Pass123@localhost/cricbuzz_db")

# Step 2: Create table if it doesn't exist
def create_recent_matches_table(engine):
    """
    Creates 'recent_matches' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS recent_matches (
        match_id BIGINT PRIMARY KEY,
        match_desc VARCHAR(100),
        team1 VARCHAR(50),
        team2 VARCHAR(50),
        start_date DATETIME,
        status VARCHAR(100),
        state VARCHAR(50),
        venue VARCHAR(100),
        venue_city VARCHAR(100),
        series_name VARCHAR(150),
        match_format VARCHAR(20),
        team1_score VARCHAR(50),
        team2_score VARCHAR(50)
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'recent_matches' is ready.")

# Step 3: Insert DataFrame into MySQL
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into a specified MySQL table.
    """
    df = df.where(pd.notnull(df), None)  # Replace NaN with None
    df.to_sql(table_name, con=engine, if_exists="append", index=False, method="multi")
    print(f"✅ Data inserted successfully into '{table_name}'!")

# Step 4: Connect, create table, and insert data
engine = create_mysql_engine()
create_recent_matches_table(engine)

# 🔁 Replace this with your actual DataFrame
# Example:
# df_recent_matches = pd.DataFrame([...])
# Make sure it matches the table schema

insert_df_to_mysql(df_recent_matches, engine, table_name="recent_matches")
# Out:
# ✅ Table 'recent_matches' is ready.
# ✅ Data inserted successfully into 'recent_matches'!

# %%
import requests
import pandas as pd

# Extract stat for one format
def extract_stat(data, stat_name, format_type):
    headers = data.get("headers", [])
    values_list = data.get("values", [])
    
    if format_type not in headers:
        return 0
    
    col_index = headers.index(format_type)
    
    for item in values_list:
        row = item.get("values", [])
        if row and row[0].lower() == stat_name.lower():
            value = row[col_index]
            try:
                return int(value)
            except (ValueError, TypeError):
                return 0
    return 0

# Sum stats across formats
def sum_stats_across_formats(data, stat_name):
    # Use exact headers from API: Test, ODI, T20, IPL
    formats = ["Test", "ODI", "T20"]
    total = 0
    for fmt in formats:
        total += extract_stat(data, stat_name, fmt)
    return total

# Fetch player summary
def fetch_players_summary(player_ids):
    all_players = []
    for player_id in player_ids:
        try:
            # Player general info
            player_info = fetch_api(f"https://cricbuzz-cricket2.p.rapidapi.com/stats/v1/player/{player_id}")
            # Batting stats
            batting_info = fetch_api(f"https://cricbuzz-cricket2.p.rapidapi.com/stats/v1/player/{player_id}/batting")
            # Bowling stats
            bowling_info = fetch_api(f"https://cricbuzz-cricket2.p.rapidapi.com/stats/v1/player/{player_id}/bowling")
            
            player_data = {
                "player_id": player_id,
                "full_name": player_info.get("name"),
                "name": player_info.get("nickName"),
                "country": player_info.get("intlTeam"),
                "playing_role": player_info.get("role"),
                "batting_style": player_info.get("bat"),
                "bowling_style": player_info.get("bowl"),
                "total_runs": sum_stats_across_formats(batting_info, "Runs"),
                "total_wickets": sum_stats_across_formats(bowling_info, "Wickets")
            }
            
            all_players.append(player_data)
            print(f" Player {player_id} data fetched")
        except Exception as e:
            print(f" Error fetching player {player_id}: {e}")
    
    return all_players

# Player IDs to fetch
player_ids = [576, 25, 265, 1413, 11808, 8733, 10808, 13217, 10551, 9311, 587, 8808, 9647, 10276, 10744, 8271,11540, 18504, 9720, 10738, 9551, 11177,
               10100, 8313]  

# Fetch data & convert to DataFrame
players_summary = fetch_players_summary(player_ids)
df_players = pd.DataFrame(players_summary)

# Display final DataFrame
print("Final Player Summary DataFrame:")
df_players
# Out:
#  Player 576 data fetched
#  Player 25 data fetched
#  Player 265 data fetched
#  Player 1413 data fetched
#  Player 11808 data fetched
#  Player 8733 data fetched
#  Player 10808 data fetched
#  Player 13217 data fetched
#  Player 10551 data fetched
#  Player 9311 data fetched
#  Player 587 data fetched
#  Player 8808 data fetched
#  Player 9647 data fetched
#  Player 10276 data fetched
#  Player 10744 data fetched
#  Player 8271 data fetched
#  Player 11540 data fetched
#  Player 18504 data fetched
#  Player 9720 data fetched
#  Player 10738 data fetched
#  Player 9551 data fetched
#  Player 11177 data fetched
#  Player 10100 data fetched
#  Player 8313 data fetched
# Final Player Summary DataFrame:
#     player_id           full_name               name       country  \
# 0         576        Rohit Sharma              Rohit         India
# 1          25    Sachin Tendulkar          Tendulkar         India
# 2         265            MS Dhoni              Dhoni         India
# 3        1413         Virat Kohli              Kohli         India
# 4       11808        Shubman Gill               Gill         India
# 5        8733            KL Rahul              Rahul         India
# 6       10808      Mohammed Siraj              Siraj         India
# 7       13217      Arshdeep Singh     Arshdeep Singh         India
# 8       10551     Prasidh Krishna            Prasidh         India
# 9        9311      Jasprit Bumrah             Bumrah         India
# 10        587     Ravindra Jadeja             Jadeja         India
# 11       8808          Axar Patel               Axar         India
# 12       9647       Hardik Pandya      Hardik Pandya         India
# 13      10276        Ishan Kishan       Ishan Kishan         India
# 14      10744        Rishabh Pant               Pant         India
# 15       8271        Sanju Samson             Samson         India
# 16      11540        Jofra Archer       Jofra Archer       England
# 17      18504  Maheesh Theekshana         Theekshana     Sri Lanka
# 18       9720      Keshav Maharaj            Maharaj  South Africa
# 19      10738         Rashid Khan        Rashid Khan   Afghanistan
# 20       9551   Michael Bracewell  Michael Bracewell   New Zealand
# 21      11177     Rachin Ravindra           Ravindra   New Zealand
# 22      10100    Mitchell Santner            Santner   New Zealand
# 23       8313        Jason Holder             Holder   West Indies
#
#           playing_role     batting_style          bowling_style  total_runs  \
# 0              Batsman  Right Handed Bat     Right-arm offbreak       19700
# 1              Batsman  Right Handed Bat     Right-arm legbreak       34357
# 2           WK-Batsman  Right Handed Bat       Right-arm medium       17266
# 3              Batsman  Right Handed Bat       Right-arm medium       27599
# 4              Batsman  Right Handed Bat     Right-arm offbreak        6115
# 5           WK-Batsman  Right Handed Bat                   None        9097
# 6               Bowler  Right Handed Bat         Right-arm fast         220
# 7               Bowler   Left Handed Bat   Left-arm fast-medium         111
# 8               Bowler  Right Handed Bat         Right-arm fast          12
# 9               Bowler  Right Handed Bat         Right-arm fast         440
# 10  Bowling Allrounder   Left Handed Bat      Left-arm orthodox        7207
# 11  Bowling Allrounder   Left Handed Bat      Left-arm orthodox        2021
# 12  Batting Allrounder  Right Handed Bat  Right-arm fast-medium        4296
# 13          WK-Batsman   Left Handed Bat                   None        1807
# 14          WK-Batsman   Left Handed Bat                   None        5507
# 15          WK-Batsman  Right Handed Bat                   None        1479
# 16              Bowler  Right Handed Bat         Right-arm fast         437
# 17              Bowler  Right Handed Bat     Right-arm offbreak         460
# 18              Bowler  Right Handed Bat      Left-arm orthodox        1689
# 19  Bowling Allrounder  Right Handed Bat     Right-arm legbreak        2116
# 20  Batting Allrounder   Left Handed Bat     Right-arm offbreak        1407
# 21  Batting Allrounder   Left Handed Bat      Left-arm orthodox        2909
# 22  Bowling Allrounder   Left Handed Bat      Left-arm orthodox        3258
# 23  Bowling Allrounder  Right Handed Bat  Right-arm fast-medium        5987
#
#     total_wickets
# 0              12
# 1             201
# 2               1
# 3               9
# 4               0
# 5               0
# 6             208
# 7             115
# 8              59
# 9             462
# 10            615
# 11            202
# 12            206
# 13              0
# 14              0
# 15              0
# 16            157
# 17            148
# 18            313
# 19            417
# 20             91
# 21             45
# 22            328
# 23            407

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# ✅ Step 1: Create MySQL engine with correct password
def create_mysql_engine():
    """
    Creates and returns a SQLAlchemy MySQL engine using your credentials.
    """
    return create_engine("mysql+pymysql://root:Pass123@localhost/cricbuzz_db")

# ✅ Step 2: Create 'players' table if it doesn't exist
def create_players_table(engine):
    """
    Creates 'players' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS players (
        player_id INT PRIMARY KEY,
        full_name VARCHAR(100),
        name VARCHAR(150),
        country VARCHAR(50),
        playing_role VARCHAR(50),
        batting_style VARCHAR(50),
        bowling_style VARCHAR(50),
        total_runs INT,
        total_wickets INT
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'players' is ready.")

# ✅ Step 3: Insert DataFrame into MySQL
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into a specified MySQL table.
    """
    df = df.where(pd.notnull(df), None)  # Replace NaN with None
    df.to_sql(table_name, con=engine, if_exists="append", index=False, method="multi")
    print(f"✅ Data inserted successfully into '{table_name}'!")

# ✅ Step 4: Connect, create table, and insert data
engine = create_mysql_engine()
create_players_table(engine)

# 🔁 Replace this with your actual DataFrame
# Example:
# df_players = pd.DataFrame([...])
# Make sure it matches the table schema

insert_df_to_mysql(df_players, engine, table_name="players")
# Out:
# ✅ Table 'players' is ready.
# ✅ Data inserted successfully into 'players'!

# %%
# Helper: Format innings scores
def format_scores(team_score):
    if not team_score:
        return ""
    scores = []
    for key, innings in team_score.items():
        if innings:
            runs = innings.get("runs", 0)
            wickets = innings.get("wickets", 0)
            overs = innings.get("overs", 0)
            scores.append(f"{runs}/{wickets} ({overs} ov)")
    return " | ".join(scores)

# Extract match details from one series
def extract_series_matches(data):
    all_matches = []
    match_details = data.get("matchDetails", [])

    for item in match_details:
        map_data = item.get("matchDetailsMap")
        if not map_data:
            continue

        matches = map_data.get("match", [])
        for m in matches:
            info = m.get("matchInfo", {})
            score = m.get("matchScore", {})

            team1_score = format_scores(score.get("team1Score"))
            team2_score = format_scores(score.get("team2Score"))

            start_dt = datetime.fromtimestamp(int(info.get("startDate", 0))/1000)
            end_dt = datetime.fromtimestamp(int(info.get("endDate", 0))/1000)

            match_data = {
                "match_id": info.get("matchId"),
                "match_desc": info.get("matchDesc"),
                "team1": info.get("team1", {}).get("teamName"),
                "team2": info.get("team2", {}).get("teamName"),
                "start_date": start_dt,
                "end_date": end_dt,
                "status": info.get("status"),
                "state": info.get("state"),
                "venue": info.get("venueInfo", {}).get("ground"),
                "series_name": info.get("seriesName"),
                "match_format": info.get("matchFormat"),
                "team1_score": team1_score,
                "team2_score": team2_score
            }
            all_matches.append(match_data)

    return pd.DataFrame(all_matches)

# Fetch multiple series
series_ids = [8393, 4905, 8528, 3692]  
all_matches_df = pd.DataFrame()

for sid in series_ids:
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{sid}"
    data = fetch_api(url)
    df = extract_series_matches(data)
    all_matches_df = pd.concat([all_matches_df, df], ignore_index=True)

# Display final combined DataFrame
print("All Series Matches DataFrame:")
all_matches_df
# Out:
# All Series Matches DataFrame:
#     match_id match_desc       team1       team2          start_date  \
# 0     100220   1st Test       INDIA  BANGLADESH 2024-09-19 09:30:00
# 1     100229   2nd Test       INDIA  BANGLADESH 2024-09-27 09:30:00
# 2     100238   1st T20I       INDIA  BANGLADESH 2024-10-06 19:00:00
# 3     100247   2nd T20I       INDIA  BANGLADESH 2024-10-09 19:00:00
# 4     100256   3rd T20I       INDIA  BANGLADESH 2024-10-12 19:00:00
# 5      56955    1st ODI  BANGLADESH       INDIA 2022-12-04 11:30:00
# 6      56962    2nd ODI  BANGLADESH       INDIA 2022-12-07 11:30:00
# 7      56964    3rd ODI  BANGLADESH       INDIA 2022-12-10 11:30:00
# 8      56969   1st Test  BANGLADESH       INDIA 2022-12-14 09:00:00
# 9      56976   2nd Test  BANGLADESH       INDIA 2022-12-22 09:00:00
# 10    101535   1st T20I   SRI LANKA       INDIA 2024-07-27 19:00:00
# 11    101540   2nd T20I   SRI LANKA       INDIA 2024-07-28 19:00:00
# 12    101545   3rd T20I   SRI LANKA       INDIA 2024-07-30 19:00:00
# 13    101549    1st ODI   SRI LANKA       INDIA 2024-08-02 14:30:00
# 14    101550    2nd ODI   SRI LANKA       INDIA 2024-08-04 14:30:00
# 15    101555    3rd ODI   SRI LANKA       INDIA 2024-08-07 14:30:00
# 16     38632   1st T20I       INDIA   SRI LANKA 2022-02-24 19:00:00
# 17     38637   2nd T20I       INDIA   SRI LANKA 2022-02-26 19:00:00
# 18     38642   3rd T20I       INDIA   SRI LANKA 2022-02-27 19:00:00
# 19     38622   1st Test       INDIA   SRI LANKA 2022-03-04 09:30:00
# 20     38627   2nd Test       INDIA   SRI LANKA 2022-03-12 14:00:00
#
#               end_date                                             status  \
# 0  2024-09-23 09:30:00                              India won by 280 runs
# 1  2024-10-01 09:30:00                                India won by 7 wkts
# 2  2024-10-06 19:00:00                                India won by 7 wkts
# 3  2024-10-09 19:00:00                               India won by 86 runs
# 4  2024-10-12 19:00:00                              India won by 133 runs
# 5  2022-12-04 11:30:00                            Bangladesh won by 1 wkt
# 6  2022-12-07 11:30:00                           Bangladesh won by 5 runs
# 7  2022-12-10 11:30:00                              India won by 227 runs
# 8  2022-12-18 09:00:00                              India won by 188 runs
# 9  2022-12-26 09:00:00                                India won by 3 wkts
# 10 2024-07-27 19:00:00                               India won by 43 runs
# 11 2024-07-28 19:00:00  India won by 7 wkts (2nd innings reduced to 8 ...
# 12 2024-07-30 19:00:00              Match tied (India won the super over)
# 13 2024-08-02 14:30:00                                         Match tied
# 14 2024-08-04 14:30:00                           Sri Lanka won by 32 runs
# 15 2024-08-07 14:30:00                          Sri Lanka won by 110 runs
# 16 2022-02-24 19:00:00                               India won by 62 runs
# 17 2022-02-26 19:00:00                                India won by 7 wkts
# 18 2022-02-27 19:00:00                                India won by 6 wkts
# 19 2022-03-08 09:30:00               India won by an innings and 222 runs
# 20 2022-03-16 14:00:00                              India won by 238 runs
#
#        state                                              venue  \
# 0   complete                             MA Chidambaram Stadium
# 1   complete                                         Green Park
# 2   complete         Shrimant Madhavrao Scindia Cricket Stadium
# 3   complete                               Arun Jaitley Stadium
# 4   complete                 Rajiv Gandhi International Stadium
# 5   complete                      Shere Bangla National Stadium
# 6   complete                      Shere Bangla National Stadium
# 7   complete  Bir Sreshtho Flight Lieutenant Matiur Rahman S...
# 8   complete  Bir Sreshtho Flight Lieutenant Matiur Rahman S...
# 9   complete                      Shere Bangla National Stadium
# 10  complete            Pallekele International Cricket Stadium
# 11  complete            Pallekele International Cricket Stadium
# 12  complete            Pallekele International Cricket Stadium
# 13  complete                                R.Premadasa Stadium
# 14  complete                                R.Premadasa Stadium
# 15  complete                                R.Premadasa Stadium
# 16  complete  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 17  complete       Himachal Pradesh Cricket Association Stadium
# 18  complete       Himachal Pradesh Cricket Association Stadium
# 19  complete       Punjab Cricket Association IS Bindra Stadium
# 20  complete                              M.Chinnaswamy Stadium
#
#                        series_name match_format  \
# 0   Bangladesh tour of India, 2024         TEST
# 1   Bangladesh tour of India, 2024         TEST
# 2   Bangladesh tour of India, 2024          T20
# 3   Bangladesh tour of India, 2024          T20
# 4   Bangladesh tour of India, 2024          T20
# 5   India tour of Bangladesh, 2022          ODI
# 6   India tour of Bangladesh, 2022          ODI
# 7   India tour of Bangladesh, 2022          ODI
# 8   India tour of Bangladesh, 2022         TEST
# 9   India tour of Bangladesh, 2022         TEST
# 10   India tour of Sri Lanka, 2024          T20
# 11   India tour of Sri Lanka, 2024          T20
# 12   India tour of Sri Lanka, 2024          T20
# 13   India tour of Sri Lanka, 2024          ODI
# 14   India tour of Sri Lanka, 2024          ODI
# 15   India tour of Sri Lanka, 2024          ODI
# 16   Sri Lanka tour of India, 2022          T20
# 17   Sri Lanka tour of India, 2022          T20
# 18   Sri Lanka tour of India, 2022          T20
# 19   Sri Lanka tour of India, 2022         TEST
# 20   Sri Lanka tour of India, 2022         TEST
#
#                              team1_score                          team2_score
# 0     376/10 (91.2 ov) | 287/4 (64.0 ov)  149/10 (47.1 ov) | 234/10 (62.1 ov)
# 1       285/9 (34.4 ov) | 98/3 (17.2 ov)  233/10 (74.2 ov) | 146/10 (47.0 ov)
# 2                        132/3 (11.5 ov)                     127/10 (19.5 ov)
# 3                        221/9 (20.0 ov)                      135/9 (20.0 ov)
# 4                        297/6 (20.0 ov)                      164/7 (20.0 ov)
# 5                        187/9 (46.0 ov)                     186/10 (41.2 ov)
# 6                        271/7 (50.0 ov)                      266/9 (50.0 ov)
# 7                       182/10 (34.0 ov)                      409/8 (50.0 ov)
# 8   150/10 (55.5 ov) | 324/10 (113.2 ov)  404/10 (133.5 ov) | 258/2 (61.4 ov)
# 9    227/10 (73.5 ov) | 231/10 (70.2 ov)   314/10 (86.3 ov) | 145/7 (47.0 ov)
# 10                      170/10 (19.2 ov)                      213/7 (20.0 ov)
# 11                       161/9 (20.0 ov)                        81/3 (6.3 ov)
# 12                       137/8 (20.0 ov)                      137/9 (20.0 ov)
# 13                       230/8 (50.0 ov)                     230/10 (47.5 ov)
# 14                       240/9 (50.0 ov)                     208/10 (42.2 ov)
# 15                       248/7 (50.0 ov)                     138/10 (26.1 ov)
# 16                       199/2 (20.0 ov)                      137/6 (20.0 ov)
# 17                       186/3 (17.1 ov)                      183/5 (20.0 ov)
# 18                       148/4 (16.5 ov)                      146/5 (20.0 ov)
# 19                      574/8 (129.2 ov)  174/10 (65.0 ov) | 178/10 (60.0 ov)
# 20    252/10 (59.1 ov) | 303/9 (68.5 ov)  109/10 (35.5 ov) | 208/10 (59.3 ov)

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# ✅ Step 1: Create MySQL engine with correct credentials
def create_mysql_engine():
    """
    Creates and returns a SQLAlchemy MySQL engine using your credentials.
    """
    # 🔐 Use strong credentials and avoid hardcoding in production
    return create_engine("mysql+pymysql://root:Pass123@localhost/cricbuzz_db")

# ✅ Step 2: Create 'series_matches' table if it doesn't exist
def create_series_matches_table(engine):
    """
    Creates 'series_matches' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS series_matches (
        match_id BIGINT PRIMARY KEY,
        match_desc VARCHAR(100),
        team1 VARCHAR(50),
        team2 VARCHAR(50),
        start_date DATETIME,
        end_date DATETIME,
        status VARCHAR(100),
        state VARCHAR(50),
        venue VARCHAR(100),
        series_name VARCHAR(150),
        match_format VARCHAR(20),
        team1_score VARCHAR(50),
        team2_score VARCHAR(50)
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'series_matches' is ready.")

# ✅ Step 3: Insert DataFrame into MySQL
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into a specified MySQL table.
    """
    # 🧼 Clean NaNs to avoid SQL errors
    df = df.where(pd.notnull(df), None)

    # ⚠️ Use 'append' to preserve existing data
    # 💡 Use 'multi' for faster bulk inserts
    df.to_sql(table_name, con=engine, if_exists="append", index=False, method="multi")
    print(f"✅ Data inserted successfully into '{table_name}'!")

# ✅ Step 4: Connect, create table, and insert data
engine = create_mysql_engine()
create_series_matches_table(engine)

# 🔁 Replace this with your actual DataFrame
# Make sure it matches the table schema exactly
# Example:
# all_matches_df = pd.DataFrame([...])

insert_df_to_mysql(all_matches_df, engine, table_name="series_matches")
# Out:
# ✅ Table 'series_matches' is ready.
# ✅ Data inserted successfully into 'series_matches'!

# %%
import requests
import pandas as pd

def fetch_top_odi_runs(api_key):
    """
    Fetches top ODI run scorers from Cricbuzz API and returns a DataFrame.
    
    Parameters:
        api_key (str): Your RapidAPI key.
        
    Returns:
        pd.DataFrame: DataFrame containing top ODI run scorers.
    """
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"
    querystring = {"statsType": "mostRuns", "matchType": "2"}  # "2" = ODI
    
    headers = {
        "x-rapidapi-key": api_key,
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
    }
    
    # Fetch data from API
    response = requests.get(url, headers=headers, params=querystring)
    
    if response.status_code != 200:
        raise Exception(f"API request failed with status code {response.status_code}")
    
    data = response.json()
    
    # Extract top ODI runs into a list of dicts
    rows = []
    values = data.get("values", [])
    
    for item in values:
        row = item.get("values", [])
        if len(row) >= 6:
            try:
                rows.append({
                    "player_id": int(row[0]),
                    "player_name": row[1],
                    "matches": int(row[2]),
                    "innings": int(row[3]),
                    "runs": int(row[4]),
                    "average": float(row[5])
                })
            except ValueError:
                continue
    
    return pd.DataFrame(rows)

# --- CALL FUNCTION ---
api_key = "36954114camsh2b433ff821256e9p15a211jsn1128402c355f"  # ✅ Your RapidAPI key
df_odi_topruns = fetch_top_odi_runs(api_key)

print("Top ODI Run Scorers DataFrame:")
print(df_odi_topruns)
# Out:
# Top ODI Run Scorers DataFrame:
#     player_id     player_name  matches  innings   runs  average
# 0          25       Tendulkar      463      452  18426    44.83
# 1         104      Sangakkara      404      380  14234    41.99
# 2        1413           Kohli      302      290  14181    57.88
# 3          38       R Ponting      375      365  13704    42.04
# 4         102    S Jayasuriya      445      433  13430    32.36
# 5         101          Mahela      448      418  12650    33.38
# 6          35  Inzamam-ul-Haq      378      350  11739    39.53
# 7         213          Kallis      328      314  11579    44.36
# 8          29       S Ganguly      311      300  11363    41.02
# 9         576           Rohit      273      265  11168    48.77
# 10         27          Dravid      344      318  10889    39.17
# 11        265           Dhoni      350      297  10773    50.58
# 12        247           Gayle      301      294  10480    37.83
# 13        240          B Lara      299      289  10405    40.49
# 14        105         Dilshan      330      303  10290    39.27
# 15         34        M Yousuf      288      273   9720    41.72
# 16         36     A Gilchrist      287      279   9619    35.89
# 17        370     de Villiers      228      218   9577    53.50
# 18       3864    M Azharuddin      334      308   9378    36.92
# 19       3531         A Silva      308      296   9284    34.90

# %%
def create_top_odi_runs_table(engine):
    create_query = """
    CREATE TABLE IF NOT EXISTS top_odi_runs (
        player_id BIGINT PRIMARY KEY,
        player_name VARCHAR(100),
        matches INT,
        innings INT,
        runs INT,
        average FLOAT
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("Table 'top_odi_runs' is ready.")

create_top_odi_runs_table(engine)

insert_df_to_mysql(df_odi_topruns, engine, table_name="top_odi_runs")
# Out:
# Table 'top_odi_runs' is ready.
# ✅ Data inserted successfully into 'top_odi_runs'!

# %%
import pandas as pd

# Function to extract venue details using your fetch_api function
def extract_venue_details(venue_ids):
    """
    Takes a list of venue IDs, fetches data from the API for each ID,
    and returns a DataFrame with venue_id, venue_name, city, country, capacity.
    If API response is empty, still returns an empty row for that ID.
    """
    all_venues = []

    for vid in venue_ids:
        url = f"https://cricbuzz-cricket.p.rapidapi.com/venues/v1/{vid}"
        try:
            data = fetch_api(url)  
        except Exception as e:
            print(f" Error fetching venue {vid}: {e}")
            data = {}

        # Always append a row, even if data is empty
        venue_info = {
            "venue_id": vid,
            "venue_name": data.get("ground", ""),
            "city": data.get("city", ""),
            "country": data.get("country", ""),
            "capacity": data.get("capacity", "")
        }
        all_venues.append(venue_info)

    return pd.DataFrame(all_venues)


# Example usage
venue_ids = [41, 34, 27, 31, 81, 19, 10, 153, 50, 40, 80, 485, 87, 11]
df_venues = extract_venue_details(venue_ids)

print("Venue Details DataFrame:")
df_venues
# Out:
# Venue Details DataFrame:
#     venue_id                                         venue_name       city  \
# 0         41                                          Eden Park   Auckland
# 1         34                              Sydney Cricket Ground     Sydney
# 2         27                              M.Chinnaswamy Stadium  Bengaluru
# 3         31                                       Eden Gardens    Kolkata
# 4         81                                   Wankhede Stadium     Mumbai
# 5         19                                             Lord's     London
# 6         10                                  Brabourne Stadium     Mumbai
# 7        153                Dubai International Cricket Stadium      Dubai
# 8         50                              Narendra Modi Stadium  Ahmedabad
# 9         40                                      Adelaide Oval   Adelaide
# 10        80                 Rajiv Gandhi International Stadium  Hyderabad
# 11       485  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...    Lucknow
# 12        87                           Melbourne Cricket Ground  Melbourne
# 13        11                             MA Chidambaram Stadium    Chennai
#
#                  country                                  capacity
# 0            New Zealand                                    41,000
# 1              Australia                                    48,000
# 2                  India                                    40,000
# 3                  India                                     63000
# 4                  India                                    33,000
# 5                England                                     30000
# 6                  India                                    20,000
# 7   United Arab Emirates                                    25,000
# 8                  India                                   132,000
# 9              Australia          53,583 (including standing room)
# 10                 India                                     38000
# 11                 India                                     50000
# 12             Australia  100000 (approx, including standing room)
# 13                 India                                     50000

# %%
from sqlalchemy import text

# Create table for venue details
def create_venues_table(engine):
    """
    Creates 'venues' table in MySQL if it doesn't already exist.
    Schema matches the DataFrame returned by extract_venue_details().
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS venues (
        venue_id BIGINT PRIMARY KEY,
        venue_name VARCHAR(150),
        city VARCHAR(100),
        country VARCHAR(100),
        capacity VARCHAR(50)
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("Table 'venues' is ready.")


# Create table
create_venues_table(engine)

# Insert DataFrame into MySQL
insert_df_to_mysql(df_venues, engine, table_name="venues")
# Out:
# Table 'venues' is ready.
# ✅ Data inserted successfully into 'venues'!

# %%
import pandas as pd

def extract_players_stats(player_ids):
    """
    Fetch player profile and batting stats for a list of player IDs.
    Returns a DataFrame with:
    player_id, player_name, role, test_runs, odi_runs, t20_runs
    """
    all_players = []

    for pid in player_ids:
        # --- Fetch profile ---
        profile_url = f"https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/{pid}"
        profile_data = fetch_api(profile_url)
        
        player_name = profile_data.get("name")
        role = profile_data.get("role")
        
        # --- Fetch batting stats ---
        batting_url = f"https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/{pid}/batting"
        batting_data = fetch_api(batting_url)

        # Initialize runs
        test_runs = odi_runs = t20_runs = 0

        # Extract runs from 'values' list
        values = batting_data.get("values", [])
        for item in values:
            row = item.get("values", [])
            if row and row[0] == "Runs":
                test_runs = int(row[1]) if row[1].isdigit() else 0
                odi_runs = int(row[2]) if row[2].isdigit() else 0
                t20_runs = int(row[3]) if row[3].isdigit() else 0

        all_players.append({
            "player_id": pid,
            "player_name": player_name,
            "role": role,
            "test_runs": test_runs,
            "odi_runs": odi_runs,
            "t20_runs": t20_runs
        })

    return pd.DataFrame(all_players)

# --- Example usage ---
player_ids = [576, 1413, 265, 247, 2250, 8019, 6326]  # Add any player IDs
df_players = extract_players_stats(player_ids)
df_players
# Out:
#    player_id      player_name        role  test_runs  odi_runs  t20_runs
# 0        576     Rohit Sharma     Batsman       4301     11168      4231
# 1       1413      Virat Kohli     Batsman       9230     14181      4188
# 2        265         MS Dhoni  WK-Batsman       4876     10773      1617
# 3        247      Chris Gayle     Batsman       7215     10480      1899
# 4       2250     Steven Smith     Batsman      10477      5800      1094
# 5       8019         Joe Root     Batsman      13543      7301       893
# 6       6326  Kane Williamson     Batsman       9276      7236      2575

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# ✅ Step 1: Create MySQL engine with correct password
def create_mysql_engine():
    """
    Creates and returns a SQLAlchemy MySQL engine using your credentials.
    """
    return create_engine("mysql+pymysql://root:Pass123@localhost/cricbuzz_db")

# ✅ Step 2: Create 'players_stats' table if it doesn't exist
def create_players_stats_table(engine):
    """
    Creates 'players_stats' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS players_stats (
        player_id BIGINT PRIMARY KEY,
        player_name VARCHAR(100),
        role VARCHAR(50),
        test_runs INT,
        odi_runs INT,
        t20_runs INT
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'players_stats' is ready.")

# ✅ Step 3: Insert DataFrame into MySQL
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into a specified MySQL table.
    """
    df = df.where(pd.notnull(df), None)  # Replace NaN with None
    df.to_sql(table_name, con=engine, if_exists="append", index=False, method="multi")
    print(f"✅ Data inserted successfully into '{table_name}'!")

# ✅ Step 4: Connect, create table, and insert data
engine = create_mysql_engine()
create_players_stats_table(engine)

# 🔁 Replace this with your actual DataFrame
# Example:
# df_players = pd.DataFrame([...])
# Ensure it has columns: player_id, player_name, role, test_runs, odi_runs, t20_runs

insert_df_to_mysql(df_players, engine, "players_stats")
# Out:
# ✅ Table 'players_stats' is ready.
# ✅ Data inserted successfully into 'players_stats'!

# %%
import requests
import pandas as pd
from datetime import datetime

# STEP 1: Fetch API data
def fetch_matches_api(url, headers=None):
    if headers is None:
        headers = {
            "x-rapidapi-key": api_key,
            "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
        }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.json()

# STEP 2: Extract combined match info
def extract_combined_match_data(match_ids):
    all_matches = []

    for mid in match_ids:
        try:
            # --- API URLs (defined per match) ---
            url_match = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}"
            url_leanback = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}/leanback"

            match_data = fetch_matches_api(url_match)
            leanback_data = fetch_matches_api(url_leanback)

            match_id = match_data.get("matchid")
            series_name = match_data.get("seriesname")
            match_format = match_data.get("matchformat")
            match_date = datetime.fromtimestamp(match_data.get("startdate", 0)/1000).date() if match_data.get("startdate") else None
            venue = match_data.get("venueinfo", {}).get("ground")
            team1 = match_data.get("team1", {}).get("teamname")
            team2 = match_data.get("team2", {}).get("teamname")

            toss_info = leanback_data.get("matchheaders", {}).get("tossresults", {})
            toss_winner = toss_info.get("tosswinnername")
            toss_decision = toss_info.get("decision")

            matchheaders = leanback_data.get("matchheaders", {})
            match_winner = None
            if matchheaders.get("status"):
                match_winner = matchheaders["status"].split(" won")[0]

            match_info = {
                "match_id": match_id,
                "format": match_format,
                "series_name": series_name,
                "match_date": match_date,
                "venue": venue,
                "team1": team1,
                "team2": team2,
                "toss_winner": toss_winner,
                "toss_decision": toss_decision,
                "match_winner": match_winner,
                "win_margin": matchheaders.get("status")
            }

            all_matches.append(match_info)

        except Exception as e:
            print(f"Failed to fetch match {mid}: {e}")

    return pd.DataFrame(all_matches)

# Call for multiple matches (all variables at bottom)
api_key = "9f102fb876msh41837ea507688c2p176176jsn370dafdb4ccd"
match_ids = [100283, 100290, 130019, 82462, 116981, 116990, 76465, 105804, 87626, 87878, 116972,
              69862, 43061, 76535, 100312, 100321, 112462, 60035, 78558, 60042, 100328, 75476, 59979, 
                  59981, 30554, 32047, 77894, 91778, 91787, 105780, 105770, 105762]   # Add more IDs as needed

df_combined_matches = extract_combined_match_data(match_ids)
df_combined_matches
# Out:
#     match_id format                           series_name  match_date  \
# 0     100283    T20           England tour of India, 2025  2025-01-22
# 1     100290    T20           England tour of India, 2025  2025-01-25
# 2     130019    T20                         Asia Cup 2025  2025-09-10
# 3      82462    T20         Australia tour of India, 2023  2023-12-01
# 4     116981    T20  South Africa tour of Australia, 2025  2025-08-12
# 5     116990    T20  South Africa tour of Australia, 2025  2025-08-16
# 6      76465    T20        Pakistan tour of England, 2024  2024-05-25
# 7     105804    T20    South Africa tour of England, 2025  2025-09-12
# 8      87626    T20           ICC Mens T20 World Cup 2024  2024-06-09
# 9      87878    T20           ICC Mens T20 World Cup 2024  2024-06-29
# 10    116972    T20  South Africa tour of Australia, 2025  2025-08-10
# 11     69862    T20  Australia tour of South Africa, 2023  2023-09-03
# 12     43061    T20           ICC Mens T20 World Cup 2022  2022-10-23
# 13     76535    T20       Australia tour of England, 2024  2024-09-13
# 14    100312    ODI           England tour of India, 2025  2025-02-06
# 15    100321    ODI           England tour of India, 2025  2025-02-09
# 16    112462    ODI            ICC Champions Trophy, 2025  2025-03-04
# 17     60035    ODI         Australia tour of India, 2023  2023-03-17
# 18     78558    ODI         Australia tour of India, 2023  2023-09-24
# 19     60042    ODI         Australia tour of India, 2023  2023-03-22
# 20    100328    ODI           England tour of India, 2025  2025-02-12
# 21     75476    ODI            ICC Cricket World Cup 2023  2023-10-14
# 22     59979    ODI         Sri Lanka tour of India, 2023  2023-01-15
# 23     59981    ODI       New Zealand tour of India, 2023  2023-01-18
# 24     30554   TEST      India tour of Australia, 2020-21  2020-12-17
# 25     32047   TEST           India tour of England, 2021  2021-08-04
# 26     77894   TEST   India tour of South Africa, 2023-24  2023-12-26
# 27     91778   TEST      India tour of Australia, 2024-25  2024-11-22
# 28     91787   TEST      India tour of Australia, 2024-25  2024-12-06
# 29    105780   TEST           India tour of England, 2025  2025-07-31
# 30    105770   TEST           India tour of England, 2025  2025-07-02
# 31    105762   TEST           India tour of England, 2025  2025-06-20
#
#                                                venue         team1  \
# 0                                       Eden Gardens         India
# 1                             MA Chidambaram Stadium         India
# 2                Dubai International Cricket Stadium         India
# 3   Shaheed Veer Narayan Singh International Stadium         India
# 4                             Marrara Cricket Ground     Australia
# 5                                   Cazaly's Stadium     Australia
# 6                                          Edgbaston       England
# 7                              Emirates Old Trafford       England
# 8        Nassau County International Cricket Stadium         India
# 9                                    Kensington Oval  South Africa
# 10                            Marrara Cricket Ground     Australia
# 11                                         Kingsmead  South Africa
# 12                          Melbourne Cricket Ground         India
# 13                                    Sophia Gardens       England
# 14              Vidarbha Cricket Association Stadium         India
# 15                                  Barabati Stadium         India
# 16               Dubai International Cricket Stadium         India
# 17                                  Wankhede Stadium         India
# 18                            Holkar Cricket Stadium         India
# 19                            MA Chidambaram Stadium         India
# 20                             Narendra Modi Stadium         India
# 21                             Narendra Modi Stadium         India
# 22                  Greenfield International Stadium         India
# 23                Rajiv Gandhi International Stadium         India
# 24                                     Adelaide Oval     Australia
# 25                                      Trent Bridge       England
# 26                                   SuperSport Park  South Africa
# 27                                     Perth Stadium     Australia
# 28                                     Adelaide Oval     Australia
# 29                                   Kennington Oval       England
# 30                                         Edgbaston       England
# 31                                        Headingley       England
#
#                    team2   toss_winner toss_decision  match_winner  \
# 0                England         India       Bowling         India
# 1                England         India       Bowling         India
# 2   United Arab Emirates         India       Bowling         India
# 3              Australia     Australia       Bowling         India
# 4           South Africa     Australia       Bowling  South Africa
# 5           South Africa     Australia       Bowling     Australia
# 6               Pakistan      Pakistan       Bowling       England
# 7           South Africa  South Africa       Bowling       England
# 8               Pakistan      Pakistan       Bowling         India
# 9                  India         India       Batting         India
# 10          South Africa  South Africa       Bowling     Australia
# 11             Australia  South Africa       Batting     Australia
# 12              Pakistan         India       Bowling         India
# 13             Australia       England       Bowling       England
# 14               England       England       Batting         India
# 15               England       England       Batting         India
# 16             Australia     Australia       Batting         India
# 17             Australia         India       Bowling         India
# 18             Australia     Australia       Bowling         India
# 19             Australia     Australia       Batting     Australia
# 20               England       England       Bowling         India
# 21              Pakistan         India       Bowling         India
# 22             Sri Lanka         India       Batting         India
# 23           New Zealand         India       Batting         India
# 24                 India                                 Australia
# 25                 India                               Match drawn
# 26                 India  South Africa       Bowling  South Africa
# 27                 India         India       Batting         India
# 28                 India         India       Batting     Australia
# 29                 India       England       Bowling         India
# 30                 India       England       Bowling         India
# 31                 India       England       Bowling       England
#
#                                            win_margin
# 0                                 India won by 7 wkts
# 1                                 India won by 2 wkts
# 2                                 India won by 9 wkts
# 3                                India won by 20 runs
# 4                         South Africa won by 53 runs
# 5                             Australia won by 2 wkts
# 6                              England won by 23 runs
# 7                             England won by 146 runs
# 8                                 India won by 6 runs
# 9                                 India won by 7 runs
# 10                           Australia won by 17 runs
# 11                            Australia won by 5 wkts
# 12                                India won by 4 wkts
# 13                              England won by 3 wkts
# 14                                India won by 4 wkts
# 15                                India won by 4 wkts
# 16                                India won by 4 wkts
# 17                                India won by 5 wkts
# 18  India won by 99 runs (2nd innings reduced to 3...
# 19                           Australia won by 21 runs
# 20                              India won by 142 runs
# 21                                India won by 7 wkts
# 22                              India won by 317 runs
# 23                               India won by 12 runs
# 24                            Australia won by 8 wkts
# 25                                        Match drawn
# 26         South Africa won by an innings and 32 runs
# 27                              India won by 295 runs
# 28                           Australia won by 10 wkts
# 29                                India won by 6 runs
# 30                              India won by 336 runs
# 31                              England won by 5 wkts

# %%
# Import required libraries
from sqlalchemy import create_engine, text
import pandas as pd

# ---------- Function to create SQLAlchemy engine ----------
def create_mysql_engine(user, password, host, database):
    """
    Creates a SQLAlchemy engine for MySQL.
    """
    connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"
    return create_engine(connection_string)

# ---------- Function to create table ----------
def create_combined_matches_table(engine):
    """
    Creates 'combined_matches' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS combined_matches (
        match_id BIGINT PRIMARY KEY,
        format VARCHAR(20),
        series_name VARCHAR(150),
        match_date DATE,
        venue VARCHAR(100),
        team1 VARCHAR(50),
        team2 VARCHAR(50),
        toss_winner VARCHAR(50),
        toss_decision VARCHAR(20),
        match_winner VARCHAR(50),
        win_margin VARCHAR(100)
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'combined_matches' is ready.")

# ---------- Function to insert DataFrame ----------
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into the specified MySQL table.
    """
    try:
        df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
        print(f"✅ Data inserted into '{table_name}' successfully.")
    except Exception as e:
        print(f"❌ Failed to insert data: {e}")

# ---------- Connect, Create Table, Insert Data ----------
engine = create_mysql_engine("root", "Pass123", "localhost", "cricbuzz_db")
create_combined_matches_table(engine)

# Make sure df_combined_matches is defined before this step
insert_df_to_mysql(df_combined_matches, engine, table_name="combined_matches")
# Out:
# ✅ Table 'combined_matches' is ready.
# ✅ Data inserted into 'combined_matches' successfully.

# %%
# Extract batting stats
def extract_batting_data(match_ids):
    all_records = []

    for mid in match_ids:
        try:
            # --- API URL per match ---
            url = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}/hscard"
            data = fetch_matches_api(url)

            # Corrected key from 'scoreCard' to 'scorecard'
            for innings in data.get("scorecard", []):
                # The team and player data are not nested under 'batTeamDetails' or 'batsmenData'
                team_name = innings.get("batteamname")
                batsmen = innings.get("batsman", [])

                for bat in batsmen:
                    all_records.append({
                        "match_id": mid,
                        "innings_no": innings.get("inningsid"),
                        "team": team_name,
                        "player_id": bat.get("id"),
                        "player_name": bat.get("name"),
                        "runs": int(bat.get("runs", 0)),
                        "balls_faced": int(bat.get("balls", 0)),
                        "fours": int(bat.get("fours", 0)),
                        "sixes": int(bat.get("sixes", 0)),
                        "strike_rate": float(bat.get("strkrate", 0)),
                        "dismissal": bat.get("outdec")
                    })
        except Exception as e:
            print(f"Failed to fetch match {mid}: {e}")

    return pd.DataFrame(all_records)

api_key = "42ba173510msh8668786dd4440a9p1855c7jsnb61dc18d9c24"
# Call for multiple matches (all variables at bottom)
match_ids = [75476, 100283, 100290, 130019, 82462, 116981, 116990, 76465, 105804, 87626, 87878, 116972,
              69862, 43061, 76535, 100312, 100321, 112462, 60035, 78558, 60042, 100328, 75476, 59979, 
                  59981, 30554, 32047, 77894, 91778, 91787, 105780, 105770, 105762] # Using a single match ID for demonstration

df_batting = extract_batting_data(match_ids)
df_batting
# Out:
#      match_id  innings_no      team  player_id    player_name  runs  \
# 0       75476           1  Pakistan      12139       Shafique    20
# 1       75476           1  Pakistan       8364    Imam-ul-Haq    36
# 2       75476           1  Pakistan       8359     Babar Azam    50
# 3       75476           1  Pakistan       9468         Rizwan    49
# 4       75476           1  Pakistan       9812   Saud Shakeel     6
# ..        ...         ...       ...        ...            ...   ...
# 886    105762           4   England      13810    Jamie Smith    44
# 887    105762           4   England       6670   Chris Woakes     0
# 888    105762           4   England      11436   Brydon Carse     0
# 889    105762           4   England      12747    Josh Tongue     0
# 890    105762           4   England      46023  Shoaib Bashir     0
#
#      balls_faced  fours  sixes  strike_rate                dismissal
# 0             24      3      0        83.33              lbw b Siraj
# 1             38      6      0        94.74  c Rahul b Hardik Pandya
# 2             58      7      0        86.21                  b Siraj
# 3             69      7      0        71.01                 b Bumrah
# 4             10      0      0        60.00      lbw b Kuldeep Yadav
# ..           ...    ...    ...          ...                      ...
# 886           55      4      2        80.00                  not out
# 887            0      0      0         0.00
# 888            0      0      0         0.00
# 889            0      0      0         0.00
# 890            0      0      0         0.00
#
# [891 rows x 11 columns]

# %%
# Import required libraries
from sqlalchemy import create_engine, text
import pandas as pd

# ---------- Function to create SQLAlchemy engine ----------
def create_mysql_engine(user, password, host, database):
    """
    Creates a SQLAlchemy engine for MySQL.
    """
    connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"
    return create_engine(connection_string)

# ---------- Function to create table ----------
def create_batting_table(engine):
    """
    Creates 'batting_data' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS batting_data (
        match_id BIGINT,
        innings_no INT,
        team VARCHAR(100),
        player_id BIGINT,
        player_name VARCHAR(100),
        runs INT,
        balls_faced INT,
        fours INT,
        sixes INT,
        strike_rate FLOAT,
        dismissal VARCHAR(200)
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'batting_data' is ready.")

# ---------- Function to insert DataFrame ----------
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into the specified MySQL table.
    """
    try:
        df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
        print(f"✅ Data inserted into '{table_name}' successfully.")
    except Exception as e:
        print(f"❌ Failed to insert data: {e}")

# ---------- Connect, Create Table, Insert Data ----------
engine = create_mysql_engine("root", "Pass123", "localhost", "cricbuzz_db")
create_batting_table(engine)

# Make sure df_batting is defined before this step
insert_df_to_mysql(df_batting, engine, table_name="batting_data")
# Out:
# ✅ Table 'batting_data' is ready.
# ✅ Data inserted into 'batting_data' successfully.

# %%
def extract_bowling_data(match_ids):
    all_records = []

    for mid in match_ids:
        try:
            # --- API URL per match ---
            url = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}/hscard"

            data = fetch_matches_api(url)

            # Corrected key from 'scoreCard' to 'scorecard'
            for innings in data.get("scorecard", []):
                team_name = innings.get("batteamname") # Get the batting team name
                
                # The bowlers data is under the 'bowler' key, not 'bowlersData'
                bowlers = innings.get("bowler", [])

                for bowler in bowlers:
                    all_records.append({
                        "match_id": mid, # Use the provided match_id
                        "player_id": bowler.get("id"),
                        "player_name": bowler.get("name"),
                        "team": team_name,
                        "overs": float(bowler.get("overs", 0)),
                        "maidens": int(bowler.get("maidens", 0)),
                        "runs_conceded": int(bowler.get("runs", 0)),
                        "wickets": int(bowler.get("wickets", 0)),
                        "economy_rate": float(bowler.get("economy", 0))
                    })
        except Exception as e:
            print(f"Failed to fetch match {mid}: {e}")

    return pd.DataFrame(all_records)
api_key = "9f102fb876msh41837ea507688c2p176176jsn370dafdb4ccd"
# Call for multiple matches (all variables at bottom)
match_ids = [75476, 100283, 100290, 130019, 82462, 116981, 116990, 76465, 105804, 87626, 87878, 116972,
              69862, 43061, 76535, 100312, 100321, 112462, 60035, 78558, 60042, 100328, 75476, 59979, 
                  59981, 30554, 32047, 77894, 91778, 91787, 105780, 105770, 105762] # Using a single match ID for demonstration

df_bowling = extract_bowling_data(match_ids)
df_bowling
# Out:
#      match_id  player_id      player_name      team  overs  maidens  \
# 0       75476       9311           Bumrah  Pakistan    7.0        1
# 1       75476      10808            Siraj  Pakistan    8.0        0
# 2       75476       9647    Hardik Pandya  Pakistan    6.0        0
# 3       75476       8292    Kuldeep Yadav  Pakistan   10.0        0
# 4       75476        587  Ravindra Jadeja  Pakistan    9.5        0
# ..        ...        ...              ...       ...    ...      ...
# 435    105762       9311   Jasprit Bumrah   England   19.0        3
# 436    105762      10808   Mohammed Siraj   England   14.0        1
# 437    105762        587  Ravindra Jadeja   England   24.0        1
# 438    105762      10551  Prasidh Krishna   England   15.0        0
# 439    105762       8683   Shardul Thakur   England   10.0        0
#
#      runs_conceded  wickets  economy_rate
# 0               19        2           2.7
# 1               50        2           6.2
# 2               34        2           5.7
# 3               35        2           3.5
# 4               38        2           3.9
# ..             ...      ...           ...
# 435             57        0           3.0
# 436             51        0           3.6
# 437            104        1           4.3
# 438             92        2           6.1
# 439             51        2           5.1
#
# [440 rows x 9 columns]

# %%
# Import required libraries
from sqlalchemy import create_engine, text
import pandas as pd

# ---------- Function to create SQLAlchemy engine ----------
def create_mysql_engine(user, password, host, database):
    """
    Creates a SQLAlchemy engine for MySQL.
    """
    connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"
    return create_engine(connection_string)

# ---------- Function to create bowling_data table ----------
def create_bowling_table(engine):
    """
    Creates 'bowling_data' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS bowling_data (
        match_id BIGINT,
        player_id BIGINT,
        player_name VARCHAR(100),
        team VARCHAR(100),
        overs FLOAT,
        maidens INT,
        runs_conceded INT,
        wickets INT,
        economy_rate FLOAT
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'bowling_data' is ready.")

# ---------- Function to insert DataFrame ----------
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into the specified MySQL table.
    """
    try:
        df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
        print(f"✅ Data inserted into '{table_name}' successfully.")
    except Exception as e:
        print(f"❌ Failed to insert data: {e}")

# ---------- Connect, Create Table, Insert Data ----------
engine = create_mysql_engine("root", "Pass123", "localhost", "cricbuzz_db")
create_bowling_table(engine)

# Make sure df_bowling is defined before this step
insert_df_to_mysql(df_bowling, engine, table_name="bowling_data")
# Out:
# ✅ Table 'bowling_data' is ready.
# ✅ Data inserted into 'bowling_data' successfully.

# %%
import requests
import pandas as pd
import re

# Provided API key
api_key = "9f102fb876msh41837ea507688c2p176176jsn370dafdb4ccd"

def fetch_players_api(url, headers=None):
    """Fetches JSON data from the specified URL using a RapidAPI key."""
    if headers is None:
        headers = {
            "x-rapidapi-key": api_key,
            "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
        }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return None

def extract_fielding_data(match_ids):
    """Extracts fielding data (catches and stumpings) for multiple matches."""
    all_fielding = []
    
    for mid in match_ids:
        try:
            url_scorecard = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}/hscard"
            scorecard_data = fetch_players_api(url_scorecard)

            if not scorecard_data:
                continue

            # Dictionary to map player names to their IDs
            player_name_to_id = {}
            score_cards = scorecard_data.get("scorecard", [])

            # First, build a name-to-ID mapping from all players in the scorecard
            for innings in score_cards:
                batsmen_list = innings.get("batsman", [])
                bowlers_list = innings.get("bowler", [])
                
                for player_info in batsmen_list + bowlers_list:
                    name = player_info.get("name")
                    if name:
                        player_name_to_id[name] = player_info.get("id")

            # Now, track fielding stats using player names
            fielding_stats = {}
            for innings in score_cards:
                batsmen_list = innings.get("batsman", [])
                
                for bat_info in batsmen_list:
                    out_desc = bat_info.get("outdec", "")
                    
                    # Regex to find catches (e.g., 'c Fielder Name')
                    catch_match = re.search(r"c\s+([a-zA-Z\s]+)\s+b\s+", out_desc)
                    if not catch_match:
                        catch_match = re.search(r"c\s+([a-zA-Z\s]+)\)$", out_desc)
                    
                    if catch_match:
                        fielder_name = catch_match.group(1).strip()
                        if fielder_name not in fielding_stats:
                            fielding_stats[fielder_name] = {"catches": 0, "stumpings": 0}
                        fielding_stats[fielder_name]["catches"] += 1
                    
                    # Regex to find stumpings (e.g., 'st Wicketkeeper Name')
                    stump_match = re.search(r"st\s+([a-zA-Z\s]+)\s+b\s+", out_desc)
                    if stump_match:
                        keeper_name = stump_match.group(1).strip()
                        if keeper_name not in fielding_stats:
                            fielding_stats[keeper_name] = {"catches": 0, "stumpings": 0}
                        fielding_stats[keeper_name]["stumpings"] += 1
            
            # Create final records using the name-to-ID mapping
            performance_id = 101
            for player_name, stats in fielding_stats.items():
                player_id = player_name_to_id.get(player_name, None)
                if player_id is not None and (stats["catches"] > 0 or stats["stumpings"] > 0):
                    fielding_record = {
                        "performance_id": performance_id,
                        "match_id": mid,
                        "player_id": player_id,
                        "catches": stats["catches"],
                        "stumpings": stats["stumpings"]
                    }
                    all_fielding.append(fielding_record)
                    performance_id += 1

        except Exception as e:
            print(f"Failed to fetch fielding data for match {mid}: {e}")

    return pd.DataFrame(all_fielding)

# Example usage
match_ids = [75476, 100283, 100290, 130019, 82462, 116981, 116990, 76465, 105804, 87626, 87878, 116972,
              69862, 43061, 76535, 100312, 100321, 112462, 60035, 78558, 60042, 100328, 75476, 59979, 
                  59981, 30554, 32047, 77894, 91778, 91787, 105780, 105770, 105762]
df_fielding = extract_fielding_data(match_ids)
df_fielding
# Out:
#      performance_id  match_id  player_id  catches  stumpings
# 0               101     75476       9311        1          0
# 1               102     75476      11808        1          0
# 2               103     75476      10799        1          0
# 3               104     75476      11186        1          0
# 4               105     75476       8367        1          0
# ..              ...       ...        ...      ...        ...
# 240             108    105762       8683        1          0
# 241             109    105762      13866        1          0
# 242             110    105762      12770        2          0
# 243             111    105762       8733        1          0
# 244             112    105762      11808        1          0
#
# [245 rows x 5 columns]

# %%
import mysql.connector
import pandas as pd

# ---------- Connect using mysql.connector ----------
def connect_mysql(user, password, host, database):
    return mysql.connector.connect(
        host=host,
        user=user,
        password=password,
        database=database
    )

# ---------- Create fielding_data_two table ----------
def create_fielding_table_two(cursor):
    create_query = """
    CREATE TABLE IF NOT EXISTS fielding_data_two (
        performance_id BIGINT PRIMARY KEY,
        match_id BIGINT,
        player_id BIGINT,
        catches INT,
        stumpings INT
    )
    """
    cursor.execute(create_query)
    print("✅ Table 'fielding_data_two' is ready.")

# ---------- Clean and validate DataFrame ----------
def clean_fielding_dataframe(df):
    df = df.copy()
    df = df.fillna(0)
    df.columns = ["performance_id", "match_id", "player_id", "catches", "stumpings"]
    df = df.astype("int")
    print("🧼 Cleaned DataFrame preview:")
    print(df.head())
    return df

# ---------- Insert using raw SQL ----------
def insert_fielding_data_raw(df, conn):
    cursor = conn.cursor()
    insert_query = """
        INSERT INTO fielding_data_two (performance_id, match_id, player_id, catches, stumpings)
        VALUES (%s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            match_id = VALUES(match_id),
            player_id = VALUES(player_id),
            catches = VALUES(catches),
            stumpings = VALUES(stumpings)
    """
    for _, row in df.iterrows():
        payload = (
            int(row["performance_id"]),
            int(row["match_id"]),
            int(row["player_id"]),
            int(row["catches"]),
            int(row["stumpings"])
        )
        print(f"📤 Inserting row: {payload}")
        try:
            cursor.execute(insert_query, payload)
            print(f"✅ Inserted/Updated performance_id {payload[0]}")
        except Exception as e:
            print(f"❌ Error for performance_id {payload[0]}: {e}")
    conn.commit()
    cursor.close()

# ---------- MAIN EXECUTION ----------
conn = connect_mysql("root", "Pass123", "localhost", "cricbuzz_db")
cursor = conn.cursor()
create_fielding_table_two(cursor)
df_cleaned = clean_fielding_dataframe(df_fielding)
insert_fielding_data_raw(df_cleaned, conn)
conn.close()
# Out:
# ✅ Table 'fielding_data_two' is ready.
# 🧼 Cleaned DataFrame preview:
#    performance_id  match_id  player_id  catches  stumpings
# 0             101     75476       9311        1          0
# 1             102     75476      11808        1          0
# 2             103     75476      10799        1          0
# 3             104     75476      11186        1          0
# 4             105     75476       8367        1          0
# 📤 Inserting row: (101, 75476, 9311, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 75476, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 75476, 10799, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 75476, 11186, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 75476, 8367, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (101, 100283, 10896, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 100283, 12086, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 100283, 7915, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 100283, 13681, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 100283, 12201, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 100283, 10479, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (101, 100290, 10945, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 100290, 14691, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 100290, 14504, 2, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 100290, 11436, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 100290, 10479, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 100290, 8502, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 100290, 11540, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (101, 130019, 8292, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 130019, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 130019, 7915, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 130019, 52638, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (101, 82462, 9453, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 82462, 9739, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 82462, 10162, 2, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 82462, 15137, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 82462, 10754, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 82462, 13940, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (101, 116981, 18568, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 116981, 13169, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 116981, 9200, 0, 1)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 116981, 8136, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 116981, 19243, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 116981, 20428, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 116981, 9554, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 116981, 20538, 2, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 116981, 9585, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 116990, 10637, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 116990, 13170, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 116990, 7662, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 116990, 15480, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 116990, 6258, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 116990, 9603, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 116990, 20538, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 116990, 9576, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 116990, 13070, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 76465, 12160, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 76465, 11186, 2, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 76465, 10799, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 76465, 14561, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 76465, 10045, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 76465, 10479, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 76465, 12201, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 76465, 6532, 2, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 76465, 6692, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 105804, 14565, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 105804, 12258, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 105804, 6639, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 105804, 9821, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 105804, 11540, 3, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 105804, 2258, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 105804, 19636, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (101, 87626, 14561, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 87626, 19013, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 87626, 8359, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 87626, 1917, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 87626, 10799, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 87626, 10408, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 87626, 7915, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 87626, 10744, 3, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 87626, 13217, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 87878, 9585, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 87878, 6349, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 87878, 9720, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 87878, 8292, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 87878, 10744, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 87878, 7915, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (101, 116972, 23346, 2, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 116972, 11432, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 116972, 10187, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 116972, 20538, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 116972, 12225, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 116972, 7662, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 116972, 18568, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 116972, 10637, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (101, 69862, 10637, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 69862, 13169, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 69862, 9456, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 69862, 6250, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 69862, 8583, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 69862, 10676, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 69862, 13320, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 69862, 14798, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (101, 43061, 1726, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 43061, 7915, 2, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 43061, 10799, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 43061, 9468, 1, 1)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 43061, 8359, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (101, 76535, 1742, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 76535, 8512, 2, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 76535, 11436, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 76535, 8136, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 76535, 15927, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 76535, 13169, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (101, 100312, 13940, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 100312, 9647, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 100312, 10479, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 100312, 10045, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 100312, 2258, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (101, 100321, 587, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 100321, 9647, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 100321, 11808, 3, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 100321, 1742, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 100321, 10479, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 100321, 8512, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (101, 112462, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 112462, 9428, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 112462, 9739, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 112462, 7662, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (101, 60035, 10808, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 60035, 587, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 60035, 9647, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 60035, 11808, 2, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 60035, 10182, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 60035, 12225, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (101, 78558, 9200, 3, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 78558, 9456, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 78558, 1593, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 78558, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (101, 60042, 8292, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 60042, 9647, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 60042, 11808, 2, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 60042, 8808, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 60042, 587, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 60042, 7710, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 60042, 1739, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 60042, 8136, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 60042, 2250, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (110, 60042, 8989, 1, 0)
# ✅ Inserted/Updated performance_id 110
# 📤 Inserting row: (101, 100328, 12254, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 100328, 12201, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 100328, 2258, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 100328, 8808, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 100328, 576, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 100328, 8733, 1, 1)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 100328, 9428, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (101, 75476, 9311, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 75476, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 75476, 10799, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 75476, 11186, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 75476, 8367, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (101, 59979, 10939, 2, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 59979, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 59979, 8733, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 59979, 8808, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 59979, 7915, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (101, 59981, 10713, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 59981, 10693, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 59981, 10100, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 59981, 8292, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 59981, 10945, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 59981, 7915, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 59981, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (101, 30554, 10182, 2, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 30554, 1994, 7, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 30554, 1649, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 30554, 8497, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 30554, 1447, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 30554, 1413, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 30554, 1448, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 30554, 12225, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 30554, 2195, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 32047, 8733, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 32047, 10744, 7, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 32047, 7909, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 32047, 10420, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 32047, 2258, 4, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 32047, 6507, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 32047, 554, 2, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 32047, 8019, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 32047, 587, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (110, 32047, 10808, 1, 0)
# ✅ Inserted/Updated performance_id 110
# 📤 Inserting row: (111, 32047, 1447, 1, 0)
# ✅ Inserted/Updated performance_id 111
# 📤 Inserting row: (101, 77894, 11209, 6, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 77894, 13630, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 77894, 2239, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 77894, 8733, 3, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 77894, 13940, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 77894, 10808, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 77894, 9585, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 77894, 9582, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 77894, 14265, 2, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 91778, 13346, 1, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 91778, 9200, 5, 1)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 91778, 6635, 2, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 91778, 2250, 3, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 91778, 10182, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 91778, 1413, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 91778, 8733, 2, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 91778, 10744, 6, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 91778, 14691, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (101, 91787, 13346, 2, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 91787, 2250, 2, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 91787, 10182, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 91787, 8497, 2, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 91787, 6635, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 91787, 576, 1, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 91787, 10744, 4, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 91787, 13940, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 91787, 24729, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (110, 91787, 9200, 4, 0)
# ✅ Inserted/Updated performance_id 110
# 📤 Inserting row: (101, 105780, 13810, 4, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 105780, 12201, 2, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 105780, 8512, 2, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 105780, 587, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 105780, 14691, 3, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 105780, 8733, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 105780, 14726, 1, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 105780, 8019, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 105780, 13681, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (110, 105780, 12770, 1, 0)
# ✅ Inserted/Updated performance_id 110
# 📤 Inserting row: (111, 105780, 10808, 1, 0)
# ✅ Inserted/Updated performance_id 111
# 📤 Inserting row: (101, 105770, 13810, 3, 1)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 105770, 12201, 1, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 105770, 11691, 1, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 105770, 12770, 2, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 105770, 8502, 2, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 105770, 8257, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 105770, 11808, 2, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 105770, 8733, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 105770, 10744, 2, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (110, 105770, 10945, 1, 0)
# ✅ Inserted/Updated performance_id 110
# 📤 Inserting row: (111, 105770, 10808, 2, 0)
# ✅ Inserted/Updated performance_id 111
# 📤 Inserting row: (101, 105762, 8019, 2, 0)
# ✅ Inserted/Updated performance_id 101
# 📤 Inserting row: (102, 105762, 13810, 4, 0)
# ✅ Inserted/Updated performance_id 102
# 📤 Inserting row: (103, 105762, 12747, 2, 0)
# ✅ Inserted/Updated performance_id 103
# 📤 Inserting row: (104, 105762, 11691, 1, 0)
# ✅ Inserted/Updated performance_id 104
# 📤 Inserting row: (105, 105762, 12201, 1, 0)
# ✅ Inserted/Updated performance_id 105
# 📤 Inserting row: (106, 105762, 8257, 2, 0)
# ✅ Inserted/Updated performance_id 106
# 📤 Inserting row: (107, 105762, 10744, 3, 0)
# ✅ Inserted/Updated performance_id 107
# 📤 Inserting row: (108, 105762, 8683, 1, 0)
# ✅ Inserted/Updated performance_id 108
# 📤 Inserting row: (109, 105762, 13866, 1, 0)
# ✅ Inserted/Updated performance_id 109
# 📤 Inserting row: (110, 105762, 12770, 2, 0)
# ✅ Inserted/Updated performance_id 110
# 📤 Inserting row: (111, 105762, 8733, 1, 0)
# ✅ Inserted/Updated performance_id 111
# 📤 Inserting row: (112, 105762, 11808, 1, 0)
# ✅ Inserted/Updated performance_id 112

# %%
def fetch_batting_multiple_matches(match_ids):
    """
    Fetches batting statistics for multiple matches and returns a DataFrame.
    
    Args:
        match_ids (list): A list of match IDs.
    
    Returns:
        pd.DataFrame: A DataFrame containing batting records.
    """
    records = []

    for match_id in match_ids:
        url = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{match_id}/hscard"
        data = fetch_matches_api(url)

        if not data:
            continue

        # Extract the match date from the top-level 'responselastupdated' key
        match_date = None
        match_date_ms = data.get("responselastupdated")
        if match_date_ms:
            match_date = datetime.fromtimestamp(match_date_ms / 1000).date()

        for innings in data.get("scorecard", []):
            innings_no = innings.get("inningsid")
            team_name = innings.get("batteamname")

            # Correct key: 'batsman' is the correct list
            batsmen_list = innings.get("batsman", [])

            for batsman in batsmen_list:
                record = {
                    "match_id": match_id,
                    "innings_no": innings_no,
                    "player_id": batsman.get("id"),
                    "player_name": batsman.get("name"),
                    "runs": int(batsman.get("runs", 0)),
                    "balls_faced": int(batsman.get("balls", 0)),
                    "strike_rate": float(batsman.get("strkrate", 0)),
                    "date": match_date
                }
                records.append(record)
    
    return pd.DataFrame(records)

api_key = "9f102fb876msh41837ea507688c2p176176jsn370dafdb4ccd"
# Your match IDs
match_ids = [75476, 100283, 100290, 130019, 82462, 116981, 116990, 76465, 105804, 87626, 87878, 116972,
              69862, 43061, 76535, 100312, 100321, 112462, 60035, 78558, 60042, 100328, 75476, 59979, 
                  59981, 30554, 32047, 77894, 91778, 91787, 105780, 105770, 105762] # Using a smaller list for a demonstration

df_all_batting = fetch_batting_multiple_matches(match_ids)
df_all_batting
# Out:
#      match_id  innings_no  player_id    player_name  runs  balls_faced  \
# 0       75476           1      12139       Shafique    20           24
# 1       75476           1       8364    Imam-ul-Haq    36           38
# 2       75476           1       8359     Babar Azam    50           58
# 3       75476           1       9468         Rizwan    49           69
# 4       75476           1       9812   Saud Shakeel     6           10
# ..        ...         ...        ...            ...   ...          ...
# 886    105762           4      13810    Jamie Smith    44           55
# 887    105762           4       6670   Chris Woakes     0            0
# 888    105762           4      11436   Brydon Carse     0            0
# 889    105762           4      12747    Josh Tongue     0            0
# 890    105762           4      46023  Shoaib Bashir     0            0
#
#      strike_rate        date
# 0          83.33  1970-01-21
# 1          94.74  1970-01-21
# 2          86.21  1970-01-21
# 3          71.01  1970-01-21
# 4          60.00  1970-01-21
# ..           ...         ...
# 886        80.00  1970-01-21
# 887         0.00  1970-01-21
# 888         0.00  1970-01-21
# 889         0.00  1970-01-21
# 890         0.00  1970-01-21
#
# [891 rows x 8 columns]

# %%
# Import required libraries
from sqlalchemy import create_engine, text
import pandas as pd

# ---------- Function to create SQLAlchemy engine ----------
def create_mysql_engine(user, password, host, database):
    """
    Creates a SQLAlchemy engine for MySQL.
    """
    connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"
    return create_engine(connection_string)

# ---------- Function to create batters_batting_data table ----------
def create_batting_table(engine):
    """
    Creates 'batters_batting_data' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS batters_batting_data (
        match_id BIGINT,
        innings_no INT,
        player_id BIGINT,
        player_name VARCHAR(100),
        runs INT,
        balls_faced INT,
        strike_rate FLOAT,
        date DATE
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'batters_batting_data' is ready.")

# ---------- Function to insert DataFrame ----------
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into the specified MySQL table.
    """
    try:
        df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
        print(f"✅ Data inserted into '{table_name}' successfully.")
    except Exception as e:
        print(f"❌ Failed to insert data: {e}")

# ---------- Connect, Create Table, Insert Data ----------
engine = create_mysql_engine("root", "Pass123", "localhost", "cricbuzz_db")
create_batting_table(engine)

# Make sure df_all_batting is defined before this step
insert_df_to_mysql(df_all_batting, engine, "batters_batting_data")
# Out:
# ✅ Table 'batters_batting_data' is ready.
# ✅ Data inserted into 'batters_batting_data' successfully.

# %%
import requests
import pandas as pd
from datetime import datetime

# ---------------- Fetch API Data ----------------
def fetch_players_api(url, headers=None):
    """Fetches JSON data from the specified URL using a RapidAPI key."""
    if headers is None:
        headers = {
            "x-rapidapi-key": api_key,
            "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
        }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from {url}: {e}")
        return None

# ---------------- Extract Bowling Innings Data ----------------
def extract_bowling_innings_data(match_ids):
    """Extracts bowling data for multiple matches, including venue information."""
    all_bowling_innings = []

    for mid in match_ids:
        try:
            # API URLs
            url_scorecard = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}/hscard"
            url_match = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}"

            scorecard_data = fetch_players_api(url_scorecard)
            match_data = fetch_players_api(url_match)

            if not scorecard_data or not match_data:
                continue

            # --- Corrected Venue Extraction ---
            venue_info = match_data.get("venueinfo", {})  # lowercase key
            venue = f"{venue_info.get('ground', '')}, {venue_info.get('city', '')}".strip(', ')
            if not venue:
                venue = venue_info.get('ground', '') or venue_info.get('city', '')

            # --- Scorecard and Bowling Data ---
            match_id = match_data.get("matchid", mid)  # lowercase key
            score_cards = scorecard_data.get("scorecard", [])  # lowercase key
            
            for innings in score_cards:
                innings_no = innings.get("inningsid", 0)  # lowercase key
                bowlers_list = innings.get("bowler", [])

                for bowler_info in bowlers_list:
                    player_id = bowler_info.get("id", 0)
                    player_name = bowler_info.get("name", "")
                    overs = float(bowler_info.get("overs", 0))
                    runs_conceded = int(bowler_info.get("runs", 0))
                    wickets = int(bowler_info.get("wickets", 0))
                    economy_rate = float(bowler_info.get("economy", 0))

                    bowling_record = {
                        "match_id": match_id,
                        "innings_no": innings_no,
                        "player_id": player_id,
                        "player_name": player_name,
                        "overs": overs,
                        "runs_conceded": runs_conceded,
                        "wickets": wickets,
                        "economy_rate": economy_rate,
                        "venue": venue
                    }

                    all_bowling_innings.append(bowling_record)

        except Exception as e:
            print(f"Failed to fetch bowling data for match {mid}: {e}")

    return pd.DataFrame(all_bowling_innings)

# ---------------- Provided API key ----------------
api_key = "856216e200msh46a1fae5dfd48b9p1fb177jsne6455d242a0b"

match_ids = [100283, 38617, 38612, 38627, 75623, 78621, 48121, 70326, 91787, 60035, 100310, 75563]

df_bowling_innings = extract_bowling_innings_data(match_ids)

df_bowling_innings
# Out:
#      match_id  innings_no  player_id         player_name  overs  \
# 0      100283           1      13217      Arshdeep Singh    4.0
# 1      100283           1       9647       Hardik Pandya    4.0
# 2      100283           1      12926  Varun Chakravarthy    4.0
# 3      100283           1       8808                Axar    4.0
# 4      100283           1      14659        Ravi Bishnoi    4.0
# ..        ...         ...        ...                 ...    ...
# 169     75563           2       9311      Jasprit Bumrah    5.0
# 170     75563           2      10808      Mohammed Siraj    7.0
# 171     75563           2       7909      Mohammed Shami    5.0
# 172     75563           2       8292       Kuldeep Yadav    2.0
# 173     75563           2        587     Ravindra Jadeja    0.4
#
#      runs_conceded  wickets  economy_rate                     venue
# 0               17        2           4.2     Eden Gardens, Kolkata
# 1               42        2          10.5     Eden Gardens, Kolkata
# 2               23        3           5.8     Eden Gardens, Kolkata
# 3               22        2           5.5     Eden Gardens, Kolkata
# 4               22        0           5.5     Eden Gardens, Kolkata
# ..             ...      ...           ...                       ...
# 169              8        1           1.6  Wankhede Stadium, Mumbai
# 170             16        3           2.3  Wankhede Stadium, Mumbai
# 171             18        5           3.6  Wankhede Stadium, Mumbai
# 172              3        0           1.5  Wankhede Stadium, Mumbai
# 173              4        1           6.0  Wankhede Stadium, Mumbai
#
# [174 rows x 9 columns]

# %%
# Import required libraries
from sqlalchemy import create_engine, text
import pandas as pd

# ---------- Function to create SQLAlchemy engine ----------
def create_mysql_engine(user, password, host, database):
    """
    Creates a SQLAlchemy engine for MySQL.
    """
    connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"
    return create_engine(connection_string)

# ---------- Function to create bowlers_bowling_venue_data table ----------
def create_bowling_innings_table(engine):
    """
    Creates 'bowlers_bowling_venue_data' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS bowlers_bowling_venue_data (
        match_id INT,
        innings_no INT,
        player_id INT,
        player_name VARCHAR(100),
        overs FLOAT,
        runs_conceded INT,
        wickets INT,
        economy_rate FLOAT,
        venue VARCHAR(200)
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'bowlers_bowling_venue_data' is ready.")

# ---------- Function to insert DataFrame ----------
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into the specified MySQL table.
    """
    try:
        df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
        print(f"✅ Data inserted into '{table_name}' successfully.")
    except Exception as e:
        print(f"❌ Failed to insert data: {e}")

# ---------- Connect, Create Table, Insert Data ----------
engine = create_mysql_engine("root", "Pass123", "localhost", "cricbuzz_db")
create_bowling_innings_table(engine)

# Make sure df_bowling_innings is defined before this step
insert_df_to_mysql(df_bowling_innings, engine, "bowlers_bowling_venue_data")
# Out:
# ✅ Table 'bowlers_bowling_venue_data' is ready.
# ✅ Data inserted into 'bowlers_bowling_venue_data' successfully.

# %%
def extract_partnerships_data(match_ids):
    """
    Extracts partnership data for multiple matches, including the wicket number.
    """
    all_partnerships = []

    for mid in match_ids:
        try:
            url_scorecard = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{mid}/hscard"
            scorecard_data = fetch_players_api(url_scorecard)

            if not scorecard_data:
                continue

            score_cards = scorecard_data.get("scorecard", [])
            
            for innings in score_cards:
                innings_no = innings.get("inningsid", 0)
                
                # Correct key for partnerships
                partnerships_list = innings.get("partnership", {}).get("partnership", [])
                
                # Use enumerate to get the wicket number based on the order in the list
                for index, partnership_info in enumerate(partnerships_list):
                    batter1_id = partnership_info.get("bat1id", 0)
                    batter2_id = partnership_info.get("bat2id", 0)
                    batter1_name = partnership_info.get("bat1name", "")
                    batter2_name = partnership_info.get("bat2name", "")
                    runs_partnership = partnership_info.get("totalruns", 0)
                    balls_faced = partnership_info.get("totalballs", 0)
                    
                    # The wicket_fallen number is the index + 1
                    wicket_fallen = index + 1

                    partnership_record = {
                        "match_id": mid,
                        "innings_no": innings_no,
                        "batter1_id": batter1_id,
                        "batter2_id": batter2_id,
                        "batter1_name": batter1_name,
                        "batter2_name": batter2_name,
                        "runs_partnership": runs_partnership,
                        "balls_faced": balls_faced,
                        "wicket_fallen": wicket_fallen
                    }

                    all_partnerships.append(partnership_record)

        except Exception as e:
            print(f"Failed to fetch partnerships data for match {mid}: {e}")

    return pd.DataFrame(all_partnerships)

api_key = "856216e200msh46a1fae5dfd48b9p1fb177jsne6455d242a0b"

# Call for multiple matches
match_ids = [38321, 50958, 59965, 48205, 48401]
df_partnerships = extract_partnerships_data(match_ids)
df_partnerships
# Out:
#     match_id  innings_no  batter1_id  batter2_id batter1_name batter2_name  \
# 0      38321           1        6534        6507          Roy     Bairstow
# 1      38321           1        6534        8019          Roy         Root
# 2      38321           1        6534        6557          Roy       Stokes
# 3      38321           1        2258        6557      Buttler       Stokes
# 4      38321           1        2258        6692      Buttler    Moeen Ali
# ..       ...         ...         ...         ...          ...          ...
# 71     48401           2        9427        8271        Hooda       Samson
# 72     48401           2        9427        8808        Hooda         Axar
# 73     48401           2        8683        8808       Thakur         Axar
# 74     48401           2        9781        8808   Avesh Khan         Axar
# 75     48401           2       10808        8808        Siraj         Axar
#
#     runs_partnership  balls_faced  wicket_fallen
# 0                 12            9              1
# 1                  0            3              2
# 2                 54           47              3
# 3                  8           21              4
# 4                 75           84              5
# ..               ...          ...            ...
# 71                27           34              5
# 72                51           33              6
# 73                22           12              7
# 74                24           19              8
# 75                 8            4              9
#
# [76 rows x 9 columns]

# %%
# Import required libraries
from sqlalchemy import create_engine, text
import pandas as pd

# ---------- Function to create SQLAlchemy engine ----------
def create_mysql_engine(user, password, host, database):
    """
    Creates a SQLAlchemy engine for MySQL.
    """
    connection_string = f"mysql+mysqlconnector://{user}:{password}@{host}/{database}"
    return create_engine(connection_string)

# ---------- Function to create players_partnerships_data table ----------
def create_partnerships_table(engine):
    """
    Creates 'players_partnerships_data' table in MySQL if it doesn't already exist.
    """
    create_query = """
    CREATE TABLE IF NOT EXISTS players_partnerships_data (
        match_id INT,
        innings_no INT,
        batter1_id INT,
        batter2_id INT,
        batter1_name VARCHAR(100),
        batter2_name VARCHAR(100),
        runs_partnership INT,
        balls_faced INT,
        wicket_fallen INT
    )
    """
    with engine.connect() as conn:
        conn.execute(text(create_query))
        print("✅ Table 'players_partnerships_data' is ready.")

# ---------- Function to insert DataFrame ----------
def insert_df_to_mysql(df, engine, table_name):
    """
    Inserts a DataFrame into the specified MySQL table.
    """
    try:
        df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
        print(f"✅ Data inserted into '{table_name}' successfully.")
    except Exception as e:
        print(f"❌ Failed to insert data: {e}")

# ---------- Connect, Create Table, Insert Data ----------
engine = create_mysql_engine("root", "Pass123", "localhost", "cricbuzz_db")
create_partnerships_table(engine)

# Make sure df_partnerships is defined before this step
insert_df_to_mysql(df_partnerships, engine, "players_partnerships_data")
# Out:
# ✅ Table 'players_partnerships_data' is ready.
# ✅ Data inserted into 'players_partnerships_data' successfully.
